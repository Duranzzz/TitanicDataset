# %%
import pandas as pd

# %%
titanicData = pd.read_csv('train.csv')

# %%
filas, columnas = titanicData.shape
print(f"La cantidad de filas es de: {filas}")
print(f"La cantidad de columnas es de: {columnas}")
# Out:
# La cantidad de filas es de: 891
# La cantidad de columnas es de: 12

# %%
print("La cantidad de valores nulos por columna son: ")
titanicData.isnull().sum()
# Out:
# La cantidad de valores nulos por columna son:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
titanicData.drop(columns=['PassengerId', 'Name', 'Ticket', 'Cabin'], inplace=True)

# %%
titanicData['Age'] = titanicData['Age'].fillna(round(titanicData['Age'].mean(), 1))

# %%
titanicData.dropna(inplace=True)

# %%
titanicData['Fare'] = titanicData['Fare'].round(2)

# %%
titanicData.to_excel('titanicData..xlsx', index=False)

# %%
titanicData.shape
# Out:
# (889, 8)
